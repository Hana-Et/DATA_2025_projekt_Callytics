# %%
import pandas as pd

file=pd.read_csv('CDR_data_collect.csv', header=[0, 1])

# %% [markdown]
# nacte soubor s vybranymi sloupci

# %%
file.to_pickle('CDR_data_collect.pkl')

# %% [markdown]
# vytvori pickel soubor

# %%
file.to_pickle('CDR_data_collect.pkl.gz', compression='gzip')

# %% [markdown]
# vytvori pickel soubor + ho zkomprimuje do gzip

# %%
pd.read_pickel('CDR_data_collect.plk')

# %% [markdown]
# nacteni souboru pickel
