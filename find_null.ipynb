# %%
import pandas as pd

# %%
df = pd.read_pickle('cdr_clean_unique_calls_update_num.pkl')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3262835 entries, 0 to 3805585
# Data columns (total 26 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   globalCallID_callManagerId         int64
#  1   globalCallID_callId                int64
#  2   origLegCallIdentifier              int64
#  3   dateTimeOrigination                datetime64[ns]
#  4   callingPartyNumber                 object
#  5   origCause_value                    int64
#  6   destLegIdentifier                  int64
#  7   originalCalledPartyNumber          object
#  8   finalCalledPartyNumber             object
#  9   destCause_value                    int64
#  10  dateTimeConnect                    datetime64[ns]
#  11  dateTimeDisconnect                 datetime64[ns]
#  12  lastRedirectDn                     string
#  13  pkid                               string
#  14  duration                           int64
#  15  origDeviceName                     string
#  16  destDeviceName                     string
#  17  origCallTerminationOnBehalfOf      int64
#  18  destCallTerminationOnBehalfOf      int64
#  19  origCalledPartyRedirectOnBehalfOf  int64
#  20  lastRedirectRedirectOnBehalfOf     int64
#  21  origCalledPartyRedirectReason      int64
#  22  lastRedirectRedirectReason         int64
#  23  joinOnBehalfOf                     int64
#  24  callSecuredStatus                  int64
#  25  unique_call_id                     int64
# dtypes: datetime64[ns](3), int64(16), object(3), string(4)
# memory usage: 672.1+ MB

# %%
df.isnull().sum()
# Out:
# globalCallID_callManagerId                0
# globalCallID_callId                       0
# origLegCallIdentifier                     0
# dateTimeOrigination                       0
# callingPartyNumber                        0
# origCause_value                           0
# destLegIdentifier                         0
# originalCalledPartyNumber                 0
# finalCalledPartyNumber                    0
# destCause_value                           0
# dateTimeConnect                      552540
# dateTimeDisconnect                        0
# lastRedirectDn                        60350
# pkid                                      0
# duration                                  0
# origDeviceName                       549251
# destDeviceName                       160123
# origCallTerminationOnBehalfOf             0
# destCallTerminationOnBehalfOf             0
# origCalledPartyRedirectOnBehalfOf         0
# lastRedirectRedirectOnBehalfOf            0
# origCalledPartyRedirectReason             0
# lastRedirectRedirectReason                0
# joinOnBehalfOf                            0
# callSecuredStatus                         0
# unique_call_id                            0
# dtype: int64

# %%
print("\n=== Počet NULL (NaN/NaT) v jednotlivých sloupcích ===")
print(df.isnull().sum())
# Out:
# === Počet NULL (NaN/NaT) v jednotlivých sloupcích ===
# globalCallID_callManagerId                0
# globalCallID_callId                       0
# origLegCallIdentifier                     0
# dateTimeOrigination                       0
# callingPartyNumber                        0
# origCause_value                           0
# destLegIdentifier                         0
# originalCalledPartyNumber                 0
# finalCalledPartyNumber                    0
# destCause_value                           0
# dateTimeConnect                      552540
# dateTimeDisconnect                        0
# lastRedirectDn                        60350
# pkid                                      0
# duration                                  0
# origDeviceName                       549251
# destDeviceName                       160123
# origCallTerminationOnBehalfOf             0
# destCallTerminationOnBehalfOf             0
# origCalledPartyRedirectOnBehalfOf         0
# lastRedirectRedirectOnBehalfOf            0
# origCalledPartyRedirectReason             0
# lastRedirectRedirectReason                0
# joinOnBehalfOf                            0
# callSecuredStatus                         0
# unique_call_id                            0
# dtype: int64

# %%
missing = df.isnull().sum()
missing[missing > 0]
# Out:
# dateTimeOrigination               2
# callingPartyNumber           550310
# originalCalledPartyNumber     60331
# finalCalledPartyNumber        48082
# dateTimeConnect              557165
# lastRedirectDn               603095
# origDeviceName               549251
# destDeviceName               160135
# dtype: int64

# %%
print("\n=== Řádky s chybějícími hodnotami ===")
print(df[df.isnull().any(axis=1)])
# Out:
# === Řádky s chybějícími hodnotami ===
#          globalCallID_callManagerId  globalCallID_callId  \
# 19                                1             16615200
# 21                                1             16615202
# 22                                1             16615204
# 24                                1             16615206
# 25                                1             16615207
# ...                             ...                  ...
# 3805560                           4              6319748
# 3805562                           4              6319755
# 3805563                           4              6319756
# 3805564                           4              6319757
# 3805571                           4              6319764
#
#          origLegCallIdentifier  dateTimeOrigination  callingPartyNumber  \
# 19                    19957612           1704098739       4322362473323
# 21                    19957617           1704098793       4322362473323
# 22                    19957620           1704098866       4322362473323
# 24                    19957625           1704098920       4322362473323
# 25                    19957627           1704098989       4322362473323
# ...                        ...                  ...                 ...
# 3805560               68494817           1711727013  b00417962368911001
# 3805562               68494843           1711727864         43321374450
# 3805563               68494845           1711727918       4373935601840
# 3805564               68494847           1711727920       4373935601840
# 3805571               68494866           1711729494         43460208088
#
#          origCause_value  destLegIdentifier originalCalledPartyNumber  \
# 19                    16           19957613                       NaN
# 21                    16           19957618                       NaN
# 22                    16           19957621                       NaN
# 24                    16           19957626                       NaN
# 25                    16           19957628                       NaN
# ...                  ...                ...                       ...
# 3805560               16           68494819                   6736800
# 3805562                0           68494844                35165177.0
# 3805563               16           68494846                       NaN
# 3805564                0           68494848              3413899623.0
# 3805571               16           68494867                       NaN
#
#         finalCalledPartyNumber  destCause_value  ...           origDeviceName  \
# 19                         NaN                0  ...  AALN/S0/0@A53202F3.m053
# 21                         NaN                0  ...  AALN/S0/0@A53202F3.m053
# 22                         NaN                0  ...  AALN/S0/0@A53202F3.m053
# 24                         NaN                0  ...  AALN/S0/0@A53202F3.m053
# 25                         NaN                0  ...  AALN/S0/0@A53202F3.m053
# ...                        ...              ...  ...                      ...
# 3805560                6736800                0  ...               CSFC84K659
# 3805562             35165177.0                0  ...          SEP04CAD2EE97F9
# 3805563                    NaN                0  ...          SEP1C27D3505539
# 3805564           3413899623.0                0  ...          SEP1C27D3505539
# 3805571                    NaN                0  ...          SEP1C27D35053AD
#
#            destDeviceName origCallTerminationOnBehalfOf  \
# 19                    NaN                            12
# 21                    NaN                            12
# 22                    NaN                            12
# 24                    NaN                            12
# 25                    NaN                            12
# ...                   ...                           ...
# 3805560  REC_Recording_01                            27
# 3805562               NaN                             5
# 3805563               NaN                            12
# 3805564               NaN                             5
# 3805571               NaN                            12
#
#         destCallTerminationOnBehalfOf  origCalledPartyRedirectOnBehalfOf  \
# 19                                  0                                  0
# 21                                  0                                  0
# 22                                  0                                  0
# 24                                  0                                  0
# 25                                  0                                  0
# ...                               ...                                ...
# 3805560                             0                                 27
# 3805562                             0                                  5
# 3805563                             0                                  0
# 3805564                             0                                  5
# 3805571                             0                                  0
#
#         lastRedirectRedirectOnBehalfOf origCalledPartyRedirectReason  \
# 19                                   0                             0
# 21                                   0                             0
# 22                                   0                             0
# 24                                   0                             0
# 25                                   0                             0
# ...                                ...                           ...
# 3805560                             27                           354
# 3805562                              5                             0
# 3805563                              0                             0
# 3805564                              5                             0
# 3805571                              0                             0
#
#          lastRedirectRedirectReason  joinOnBehalfOf  callSecuredStatus
# 19                                0               0                  0
# 21                                0               0                  0
# 22                                0               0                  0
# 24                                0               0                  0
# 25                                0               0                  0
# ...                             ...             ...                ...
# 3805560                         354              27                  0
# 3805562                           0               5                  0
# 3805563                           0               0                  0
# 3805564                           0               5                  0
# 3805571                           0               0                  0
#
# [1252883 rows x 25 columns]
