# %%
import pandas as pd

# %%
data = pd.read_pickle('CDR_soubor.pkl')

# %%
data.columns = [col[0] if isinstance(col, tuple) else col for col in data.columns]

# %% [markdown]
# poreseni hlavicky

# %%
list(data.columns[:10])
# Out:
# ['cdrRecordType',
#  'globalCallID_callManagerId',
#  'globalCallID_callId',
#  'origLegCallIdentifier',
#  'dateTimeOrigination',
#  'origNodeId',
#  'origSpan',
#  'origIpAddr',
#  'callingPartyNumber',
#  'callingPartyUnicodeLoginUserID']

# %%
chosen_data = data[[
    'globalCallID_callManagerId', 'globalCallID_callId',
    'origLegCallIdentifier', 'dateTimeOrigination',
    'callingPartyNumber', 'origCause_value', 'destLegIdentifier',
    'originalCalledPartyNumber', 'finalCalledPartyNumber',
    'destCause_value', 'dateTimeConnect', 'dateTimeDisconnect',
    'lastRedirectDn', 'pkid', 'duration', 'origDeviceName',
    'destDeviceName', 'origCallTerminationOnBehalfOf',
    'destCallTerminationOnBehalfOf', 'origCalledPartyRedirectOnBehalfOf',
    'lastRedirectRedirectOnBehalfOf', 'origCalledPartyRedirectReason',
    'lastRedirectRedirectReason', 'joinOnBehalfOf', 'callSecuredStatus'
]]

# %%
chosen_data = chosen_data.reset_index(drop=True)

# %%
poreseni spatneho indexovani

# %%
chosen_data.head(5)
# Out:
#    globalCallID_callManagerId  globalCallID_callId  origLegCallIdentifier  \
# 0                           1             16615182               19957562
# 1                           1             16615183               19957564
# 2                           1             16615184               19957566
# 3                           1             16615185               19957568
# 4                           1             16615186               19957570
#
#    dateTimeOrigination callingPartyNumber  origCause_value  destLegIdentifier  \
# 0           1704072013       437734693017               16           19957563
# 1           1704078480       436618449646               16           19957565
# 2           1704085667       436359992566               16           19957567
# 3           1704087689               9999               16           19957569
# 4           1704089234       433496903750                0           19957571
#
# ...

# %%
chosen_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3805586 entries, 0 to 3805585
# Data columns (total 25 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   globalCallID_callManagerId         int64
#  1   globalCallID_callId                int64
#  2   origLegCallIdentifier              int64
#  3   dateTimeOrigination                int64
#  4   callingPartyNumber                 object
#  5   origCause_value                    int64
#  6   destLegIdentifier                  int64
#  7   originalCalledPartyNumber          object
#  8   finalCalledPartyNumber             object
#  9   destCause_value                    int64
#  10  dateTimeConnect                    int64
#  11  dateTimeDisconnect                 int64
#  12  lastRedirectDn                     object
#  13  pkid                               object
#  14  duration                           int64
#  15  origDeviceName                     object
# ...

# %%
chosen_data.to_pickle('cdr_files_chosen_columns.pkl')

# %%
data = pd.read_pickle('CMR_soubor.pkl')

# %%
data.columns = [col[0] if isinstance(col, tuple) else col for col in data.columns]

# %%
chosen_data = data[['globalCallID_callManagerId', 'globalCallID_callId',
                    'nodeId', 'directoryNum', 'callIdentifier', 
                    'dateTimeStamp', 'numberPacketsSent', 'numberOctetsSent',
                    'numberPacketsReceived', 'numberOctetsReceived',
                    'numberPacketsLost', 'jitter', 'latency', 'pkid', 
                    'varVQMetrics', 'duration', 'videoContentType',
                    'videoContentType_channel2']]

# %%
chosen_data = chosen_data.reset_index(drop=True)

# %%
chosen_data.head(5)
# Out:
#    globalCallID_callManagerId  globalCallID_callId  nodeId    directoryNum  \
# 0                           1             16615192       1             NaN
# 1                           1             16615193       1  43429526179121
# 2                           1             16615194       1  43429526179121
# 3                           1             16615195       1  43429526179121
# 4                           1             16615196       1             NaN
#
#    callIdentifier  dateTimeStamp  numberPacketsSent  numberOctetsSent  \
# 0        19957589     1704095862                700            112000
# 1        19957592     1704096589                  0                 0
# 2        19957594     1704096596                  0                 0
# 3        19957596     1704096598                  0                 0
# 4        19957598     1704096945                588             94080
#
#    numberPacketsReceived  numberOctetsReceived  numberPacketsLost  jitter  \
# ...

# %%
chosen_data.to_pickle('cmr_files_chosen_columns.pkl')
