# %%
import pandas as pd

data = pd.read_pickle(
    "cdr_files_chosen_columns.pkl"  
)

# %%
data.head(10)
# Out:
#    globalCallID_callManagerId  globalCallID_callId  origLegCallIdentifier  \
# 0                           1             16615182               19957562
# 1                           1             16615183               19957564
# 2                           1             16615184               19957566
# 3                           1             16615185               19957568
# 4                           1             16615186               19957570
# 5                           1             16615187               19957572
# 6                           1             16615188               19957576
# 7                           1             16615189               19957578
# 8                           1             16615190               19957580
# 9                           1             16615191               19957584
#
#    dateTimeOrigination callingPartyNumber  origCause_value  destLegIdentifier  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3805586 entries, 0 to 3805585
# Data columns (total 25 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   globalCallID_callManagerId         int64
#  1   globalCallID_callId                int64
#  2   origLegCallIdentifier              int64
#  3   dateTimeOrigination                int64
#  4   callingPartyNumber                 object
#  5   origCause_value                    int64
#  6   destLegIdentifier                  int64
#  7   originalCalledPartyNumber          object
#  8   finalCalledPartyNumber             object
#  9   destCause_value                    int64
#  10  dateTimeConnect                    int64
#  11  dateTimeDisconnect                 int64
#  12  lastRedirectDn                     object
#  13  pkid                               object
#  14  duration                           int64
#  15  origDeviceName                     object
# ...

# %%
len(data.columns)
# Out:
# 25

# %%
data = data.astype({col: "string" for col in data.select_dtypes(include="object").columns})

# %%
casove_sloupce=["dateTimeOrigination", "dateTimeConnect", "dateTimeDisconnect"]
for sloupec in casove_sloupce:
    data[sloupec] = pd.to_datetime(data[sloupec], unit='s')

# %%
for sloupec in casove_sloupce:
        data[sloupec]=data[sloupec].replace(pd.Timestamp('1970-01-01 00:00:00'), pd.NaT)
data[casove_sloupce]
# Out:
#         dateTimeOrigination     dateTimeConnect  dateTimeDisconnect
# 0       2024-01-01 01:20:13 2024-01-01 01:20:14 2024-01-01 01:20:22
# 1       2024-01-01 03:08:00 2024-01-01 03:08:02 2024-01-01 03:08:14
# 2       2024-01-01 05:07:47                 NaT 2024-01-01 05:07:47
# 3       2024-01-01 05:41:29 2024-01-01 05:41:31 2024-01-01 05:42:05
# 4       2024-01-01 06:07:14 2024-01-01 06:07:15 2024-01-01 06:07:50
# ...                     ...                 ...                 ...
# 3805581 2024-03-29 19:15:54 2024-03-29 19:15:54 2024-03-29 19:16:39
# 3805582 2024-03-30 15:12:29 2024-03-30 15:12:42 2024-03-30 15:29:03
# 3805583 2024-03-30 15:34:07 2024-03-30 15:34:31 2024-03-30 16:06:17
# 3805584 2024-03-30 18:13:14 2024-03-30 18:13:31 2024-03-30 18:14:02
# 3805585 2024-03-31 10:04:59                 NaT 2024-03-31 10:05:15
#
# [3805586 rows x 3 columns]

# %%
data.head(5)
# Out:
#    globalCallID_callManagerId  globalCallID_callId  origLegCallIdentifier  \
# 0                           1             16615182               19957562
# 1                           1             16615183               19957564
# 2                           1             16615184               19957566
# 3                           1             16615185               19957568
# 4                           1             16615186               19957570
#
#   dateTimeOrigination callingPartyNumber  origCause_value  destLegIdentifier  \
# 0 2024-01-01 01:20:13       437734693017               16           19957563
# 1 2024-01-01 03:08:00       436618449646               16           19957565
# 2 2024-01-01 05:07:47       436359992566               16           19957567
# 3 2024-01-01 05:41:29               9999               16           19957569
# 4 2024-01-01 06:07:14       433496903750                0           19957571
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3805586 entries, 0 to 3805585
# Data columns (total 25 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   globalCallID_callManagerId         int64
#  1   globalCallID_callId                int64
#  2   origLegCallIdentifier              int64
#  3   dateTimeOrigination                datetime64[ns]
#  4   callingPartyNumber                 string
#  5   origCause_value                    int64
#  6   destLegIdentifier                  int64
#  7   originalCalledPartyNumber          string
#  8   finalCalledPartyNumber             string
#  9   destCause_value                    int64
#  10  dateTimeConnect                    datetime64[ns]
#  11  dateTimeDisconnect                 datetime64[ns]
#  12  lastRedirectDn                     string
#  13  pkid                               string
#  14  duration                           int64
# ...

# %% [markdown]
# nutne prevest do pickel, kvupi datatypum!

# %%
data.to_pickle("cdr_clean.pkl")
